# %% [markdown]
# # Tercer punto. Ajuste de curvas
# **Bancarrotas** (3.33 puntos). Los siguientes datos extraidos de Administrative Office of the U.S. Courts, representan el número de bancarrotas en miles entre los años 1988 y 2001.

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt

# %%
y = np.array([594.6,643.0,725.5,880.4,972.5,918.7,845.3,858.1,
                           1042.1,1317.0,1429.5,1392.0,1277.0,1386.6])
x = np.arange(8,22)

# %%
plt.plot(x+1980,y)
plt.grid()

# %% [markdown]
# 1. Ajuste las bancarrotas con polinomios de grado 1, 3 y 5. Muestre los errores de forma gráfica, ¿Qué polinómio se ajusta mejor? (2.3 puntos).
# 2. Muestre en un gráfico los datos y el polinómio que mejor se ajuste (0.5 puntos).
# 3. Usar el modelo para averiguar el número de bancarrotas a mediados de 1998 (es decir en 1998.5) y predecirlo para el año 2011. ¿Qué diferencias encuentra en cuanto a la interpolación y la extrapolación? (0.5 puntos).

# %%
# Punto 1
# Se crea una lista en donde se contendrán todas las soluciones
soluciones = []
soluciones
# Out:
# []

# %%
# Se obtiene el modelo polinomial
def f(x,beta):
    n = len(beta) - 1 #Orden del polinomio
    X = np.array([x**i for i in range(n+1)]) # Vector de potencias de la variable 'x' 
    return beta@X

# %%
#Función objetivo
def objetivo(beta,x,y):
    n = len(beta) -1
    X = np.array([x**i for i in range(n+1)])
    f = beta@X
    return np.sum((y-f)**2)

# %%
N = 5
for n in range(N):
    beta0 = np.random.rand(n+2) #Se  obtienen valores aleatorios para 'beta'
    soluciones.append(opt.minimize(objetivo,beta0,args = (x,y)))

# %%
soluciones[0]
# Out:
#       fun: 155674.76281318686
#  hess_inv: array([[ 0.0272958 , -0.00189149],
#        [-0.00189149,  0.00026827]])
#       jac: array([0., 0.])
#   message: 'Optimization terminated successfully.'
#      nfev: 54
#       nit: 7
#      njev: 18
#    status: 0
#   success: True
#         x: array([89.05077477, 64.214725  ])

# %%
soluciones[2]
# Out:
#       fun: 152011.4955329585
#  hess_inv: array([[ 1.16283926e+02, -2.59369539e+01,  1.83017171e+00,
#         -4.11894163e-02],
#        [-2.59369539e+01,  5.83580483e+00, -4.14893726e-01,
#          9.39660234e-03],
#        [ 1.83017171e+00, -4.14893726e-01,  2.97071324e-02,
#         -6.77062242e-04],
#        [-4.11894163e-02,  9.39660234e-03, -6.77062242e-04,
#          1.55210298e-05]])
#       jac: array([-0.00195312, -0.00585938, -0.00390625,  0.00976562])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 272
#       nit: 10
#      njev: 52
#    status: 2
#   success: False
#         x: array([ 9.40753051e+02, -1.30720911e+02,  1.40849196e+01, -3.23623960e-01])

# %%
soluciones[4]
# Out:
#       fun: 143766.4018055059
#  hess_inv: array([[ 5.65296100e+00, -1.02828583e+01,  2.69105368e+00,
#         -2.73310962e-01,  1.21742703e-02, -1.99177818e-04],
#        [-1.02828583e+01,  1.88927842e+01, -4.94783276e+00,
#          5.02173521e-01, -2.23415396e-02,  3.65005508e-04],
#        [ 2.69105368e+00, -4.94783276e+00,  1.30165706e+00,
#         -1.32670844e-01,  5.92469521e-03, -9.71137973e-05],
#        [-2.73310962e-01,  5.02173521e-01, -1.32670844e-01,
#          1.35800973e-02, -6.08833954e-04,  1.00149703e-05],
#        [ 1.21742703e-02, -2.23415396e-02,  5.92469521e-03,
#         -6.08833954e-04,  2.73973829e-05, -4.52211542e-07],
#        [-1.99177818e-04,  3.65005508e-04, -9.71137973e-05,
#          1.00149703e-05, -4.52211542e-07,  7.48781374e-09]])
#       jac: array([ 7.19726562e+00,  1.11015625e+02,  1.10040234e+03,  7.11936719e+03,
#        -5.88074023e+04, -3.98388232e+06])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 530
#       nit: 22
#      njev: 74
#    status: 2
#   success: False
#         x: array([-5.21711689e+04,  1.90351901e+04, -2.65495773e+03,  1.79465144e+02,
#        -5.87589091e+00,  7.47633286e-02])

# %%
plt.plot(x+1980,y, label = 'Datos reales') #Gráfica de los datos documentados
for n in range(N):
    if n%2 == 0: # Condición para obtener sólo los polinomios de grado impar
        plt.plot(x+1980,f(x,soluciones[n].x), label = 'Polinomio de grado ' + str(n+1))
plt.grid()
plt.legend()

# %%
for n in range(N):
    if n%2 == 0: # Condición para obtener sólo los polinomios de grado impar
        plt.scatter(n+1,soluciones[n].fun)
plt.xlabel('Orden del polinomio')
plt.ylabel('Error cuadrático acumulado')
plt.grid()

# %%
#Punto 2

# Gráfica de los datos documentados y el polinomio que mejor se ajusta
plt.plot(x+1980,y, label = 'Datos reales')
plt.plot(x+1980,f(x,soluciones[4].x), label = 'Polinomio de grado ' + str(5))
plt.grid()
plt.legend()

# %%
#Punto 3

#Interpolación para aproximar el número de bancarrotas a mediados del año 1998
f(1998.5-1980,soluciones[4].x)
# Out:
# 1365.7409473348525

# %%
#Extrapolación para aproximar el número de bancarrotas en el año 2011
f(2011-1980,soluciones[4].x)
# Out:
# 46853.42346172547

# %%
soluciones[4]
# Out:
#       fun: 143766.4018055059
#  hess_inv: array([[ 5.65296100e+00, -1.02828583e+01,  2.69105368e+00,
#         -2.73310962e-01,  1.21742703e-02, -1.99177818e-04],
#        [-1.02828583e+01,  1.88927842e+01, -4.94783276e+00,
#          5.02173521e-01, -2.23415396e-02,  3.65005508e-04],
#        [ 2.69105368e+00, -4.94783276e+00,  1.30165706e+00,
#         -1.32670844e-01,  5.92469521e-03, -9.71137973e-05],
#        [-2.73310962e-01,  5.02173521e-01, -1.32670844e-01,
#          1.35800973e-02, -6.08833954e-04,  1.00149703e-05],
#        [ 1.21742703e-02, -2.23415396e-02,  5.92469521e-03,
#         -6.08833954e-04,  2.73973829e-05, -4.52211542e-07],
#        [-1.99177818e-04,  3.65005508e-04, -9.71137973e-05,
#          1.00149703e-05, -4.52211542e-07,  7.48781374e-09]])
#       jac: array([ 7.19726562e+00,  1.11015625e+02,  1.10040234e+03,  7.11936719e+03,
#        -5.88074023e+04, -3.98388232e+06])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 530
#       nit: 22
#      njev: 74
#    status: 2
#   success: False
#         x: array([-5.21711689e+04,  1.90351901e+04, -2.65495773e+03,  1.79465144e+02,
#        -5.87589091e+00,  7.47633286e-02])
