# %% [markdown]
# # Péndulo Amortiguado
#
# En un péndulo con varilla de masa despreciable y longitud $L$ y una masa puntual $m$ en su extremo, el modelo que describe el movimiento se define de la siguiente manera:
# $$ \ddot\theta-\dfrac{g}{L}\sin\theta-\frac{b}{m}\dot\theta
# $$
# donde $b$ es el factor de fricción viscosa.

# %% [markdown]
# ## 1.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %% [markdown]
# Reescribiendo las variables como $x = [x_1,x_2]^T = [\theta,\dot\theta]^T$, se tiene
# $$
# \dot x = \begin{bmatrix}x_2\\
# -\frac{g}{L}\sin{x_1}-\frac{b}{mL}x_2
# \end{bmatrix}
# $$

# %%
g = 9.8
def pendulo(x,t,m=3,L=1,b=0.5):
    # Inicializar dx
    dx = np.zeros(2) # Regresar un arreglo de 2 ceros
    dx[0] = x[1]
    dx[1] = -(g/L * np.sin(x[0])) - ((b/(m*L))*x[1])
    return dx

# %%
t = np.linspace(0,10,100)
x0 = [np.pi/2,0]
x = odeint(pendulo,x0,t)
x.shape
# Out:
# (100, 2)

# %%
plt.plot(t,x[:,0],label = 'Posición')
plt.plot(t,x[:,1],label = 'Velocidad')
plt.legend()
plt.grid()

# %% [markdown]
# ## 2.

# %%
# Iterando sobre la posicióin angular
posicion = []
for i in range(100):
    posicion.append(x[i,0])
posicion[0]
# Out:
# 1.5707963267948966

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
L = 0.5
def penduloAni(i):
    plt.cla()
    plt.axis([-L-0.1,L+0.1,-L-0.1,0.1])
    line=plt.plot([0,L*np.sin(posicion[i])],[0,-L*np.cos(posicion[i])],'b',[-L-0.1,L+0.1],[0,0],'k',L*np.sin(posicion[i]),-L*np.cos(posicion[i]),'ob',ms=10)
    return line
FuncAnimation(fig,penduloAni, range(len(posicion)), repeat=False)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## 3.

# %%
# Establecer las distintas condiciones iniciales
x0_1 = [np.pi/2,0]
x0_2 = [np.pi,0]
x0_3 = [np.pi - 0.001,0]
x0_4 = [np.pi + 0.001,0]
t = np.linspace(0,10,100)

# %%
# Iterando sobre la posicióin angular
x3_1 = odeint(pendulo,x0_1,t)
x3_2 = odeint(pendulo,x0_2,t)
x3_3 = odeint(pendulo,x0_3,t)
x3_4 = odeint(pendulo,x0_4,t)
posicion1 = []
posicion2 = []
posicion3 = []
posicion4 = []
for i in range(100):
    posicion1.append(x3_1[i,0])
    posicion2.append(x3_2[i,0])
    posicion3.append(x3_3[i,0])
    posicion4.append(x3_4[i,0])

# %%
velocidad1 = []
velocidad2 = []
velocidad3 = []
velocidad4 = []
for i in range(100):
    velocidad1.append(x3_1[i,1])
    velocidad2.append(x3_2[i,1])
    velocidad3.append(x3_3[i,1])
    velocidad4.append(x3_4[i,1])

# %%
figura3 = plt.figure()
gs=figura3.add_gridspec(2,2,hspace=0.4,top=0.85) 
ax = gs.subplots()
figura3.suptitle('Solución del sistema de péndulo amortiguado')
ax[0].plot(posicion1,velocidad1,label='$\theta_0={}$'.format(x0_1))
ax[1].plot(posicion2,velocidad2,label='$\theta_0={}$'.format(x0_2))
ax[2].plot(posicion3,velocidad3,label='$\theta_0={}$'.format(x0_3))
ax[3].plot(posicion4,velocidad4,label='$\theta_0={}$'.format(x0_4))
for axes in ax:
    axes.legend()
    axes.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 5>()
#       3 ax = gs.subplots()
#       4 figura3.suptitle('Solución del sistema de péndulo amortiguado')
# ----> 5 ax[0].plot(posicion1,velocidad1,label='$\theta_0={}$'.format(x0))
#       6 ax[1].plot(posicion2,velocidad2,label='$\theta_0={}$'.format(x0))
#       7 ax[2].plot(posicion3,velocidad3,label='$\theta_0={}$'.format(x0))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
plt.plot(x[:,0],x[:,1],label = 'Posición')
plt.legend()
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 plt.plot(x[:,0],x[:,1],label = 'Posición')
#       2 plt.legend()
#       3 plt.grid()
#
# NameError: name 'x' is not defined

# %%
figura3 = plt.figure()
gs=figura3.add_gridspec(2,2,hspace=0.4,top=0.85) 
ax = gs.subplots()
figura3.suptitle('Solución del sistema de péndulo amortiguado')
ax[0].plot(t,x3_1[:,0],label='$\theta_0={}$'.format(x0_1))
ax[1].plot(t,x3_2[:,0],label='$\theta_0={}$'.format(x0_2))
ax[2].plot(t,x3_3[:,0],label='$\theta_0={}$'.format(x0_3))
ax[3].plot(t,x3_4[:,0],label='$\theta_0={}$'.format(x0_4))
for axes in ax:
    axes.legend()
    axes.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 5>()
#       3 ax = gs.subplots()
#       4 figura3.suptitle('Solución del sistema de péndulo amortiguado')
# ----> 5 ax[0].plot(t,x3_1[:,0],label='$\theta_0={}$'.format(x0_1))
#       6 ax[1].plot(t,x3_2[:,0],label='$\theta_0={}$'.format(x0_2))
#       7 ax[2].plot(t,x3_3[:,0],label='$\theta_0={}$'.format(x0_3))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'
